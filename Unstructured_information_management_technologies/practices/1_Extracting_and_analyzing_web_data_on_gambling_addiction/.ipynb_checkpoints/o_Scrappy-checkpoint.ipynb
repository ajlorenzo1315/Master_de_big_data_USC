# %% [markdown]
# En esta primera casilla creo una funcion basica de scrappy, que va a sacar la lista de frases de la pagina https://en.wikiquote.org/wiki/Maynard_James_Keenan.
#
# Importo scrappy y crochet (este utimo porq anaconda si no da error con scrappy) y hago el setup(). Esta funcion ya "arranca" scrappy, que es un entorno de bots o "spiders". Entonces tenemos que crear dicho spider.
#
# Como puedes ver va por programacion orientada a objetos con clases que reciven un spider "en blanco" y le aplican cosas. En este caso creo la funcion "QuotesToCsv" que coge el spider, le dice su nombre, urls y unos settings basicos que en este caso harán que el spider guarde el output en un archivo csv en la misma carpeta donde se encuentre el notebook.
#
# Despues creo la funcion que ejecutará a clase QuotesToCsv al crearse, que coge lo recibido de la URL, en especifico los elementos html li dentro de un ul, y los devuelve.
#
# El wait_for es simplemente para evitar el error ese que tiene el paquete con anaconda
#
# por ultimo defino la funcion que ejecuta todo que como ves crea el spider o crawler y le dice que haga su trabajo, crawl(), segun los parametros que creamos en QuotesToCsv.

# %%
#!pip3 install crochet

# %%
# scrape webpage
import scrapy
from scrapy.crawler import CrawlerRunner
# Reactor restart
from crochet import setup, wait_for

setup()

class QuotesToCsv(scrapy.Spider):
    """scrape first line of  quotes from `wikiquote` by 
    Maynard James Keenan and save to json file"""
    name = "MJKQuotesToCsv"
    start_urls = [
        'https://en.wikiquote.org/wiki/Maynard_James_Keenan',
    ]
    custom_settings = {
        'FEEDS': {
            'quotes.csv': {
                'format': 'csv',
                'overwrite': True
            }
        }
    }

    def parse(self, response):
        """parse data from urls"""
        for quote in response.css('div.mw-parser-output > ul > li'):
            yield {'quote': quote.extract()}



@wait_for(10)
def run_spider():
    """run spider with MJKQuotesToCsv"""
    crawler = CrawlerRunner()
    d = crawler.crawl(QuotesToCsv)
    return d

# %%
run_spider()

# %% [markdown]
# Como puedes comprobar si ejecutas lo anterior y abres el csv, da un resutado feo asi que lo vamos a limpiar con otra funcion.
#
# Importamos "re" que se usa para limpiar htm extraido y modificamos QuotesToCsv añadiendo un nuevo setting que le diga que despues de hacer su fincion main, es decir el parse(), le meta el output a la nueva funcion ExtractFirstLine que lo limpia
#
# ExtractFirstLine tiene dos dunciones, a principal process_item y la secundaria __remove_html_tags__, la primera basicamente prepara las frases para ser limpiadas y se las pasa a la secundaria que les quita las etiquetas html

# %%
# scrape webpage
import scrapy
from scrapy.crawler import CrawlerRunner
# text cleaning
import re
# Reactor restart
from crochet import setup, wait_for
setup()

class QuotesToCsv(scrapy.Spider):
    """scrape first line of  quotes from `wikiquote` by 
    Maynard James Keenan and save to json file"""
    name = "MJKQuotesToCsv"
    start_urls = [
        'https://en.wikiquote.org/wiki/Maynard_James_Keenan',
    ]
    custom_settings = {
        'ITEM_PIPELINES': {
            '__main__.ExtractFirstLine': 1
        },
        'FEEDS': {
            'quotes.csv': {
                'format': 'csv',
                'overwrite': True
            }
        }
    }

    def parse(self, response):
        """parse data from urls"""
        for quote in response.css('div.mw-parser-output > ul > li'):
            yield {'quote': quote.extract()}


class ExtractFirstLine(object):
    def process_item(self, item, spider):
        """text processing"""
        lines = dict(item)["quote"].splitlines()
        first_line = self.__remove_html_tags__(lines[0])

        return {'quote': first_line}

    def __remove_html_tags__(self, text):
        """remove html tags from string"""
        html_tags = re.compile('<.*?>')
        return re.sub(html_tags, '', text)

@wait_for(10)
def run_spider():
    """run spider with MJKQuotesToCsv"""
    crawler = CrawlerRunner()
    d = crawler.crawl(QuotesToCsv)
    return d

# %%
run_spider()

# %% [markdown]
# Saque el codigo de https://towardsdatascience.com/run-scrapy-code-from-jupyter-notebook-without-issues-69b7cb79530c, el concepto en si no es dificil pero el como formatear y las opciones si, te recomiendo usar chatgpt para que te formatee los settings y asi para no perder el tiempo en la documentacion

# %%
# scrape webpage
import scrapy
from scrapy.crawler import CrawlerRunner
# Reactor restart
from crochet import setup, wait_for

setup()

class QuotesToCsv(scrapy.Spider):
    """scrape first line of  quotes from `wikiquote` by 
    Maynard James Keenan and save to json file"""
    name = "MJKQuotesToCsv"
    start_urls = ['https://www.ludopatia.org/forum/default.asp']
    
    custom_settings = {
        'FEEDS': {
            'quotes.json': {
                'format': 'json',
                'overwrite': True
            }
        }
    }
    
    def start_requests(self):
        url = "https://www.ludopatia.org/forum/default.asp"
        self.root_urls = 'https://www.ludopatia.org/forum/'
        self.links_no_vistos = []
        self.links_vistos = []
        yield scrapy.Request(url, self.parse)

    def parse(self, response):
        
        print("URL de la página actual:", response.url)
        
        # Extraer todos los enlaces de la página actual
        #links = response.css('a::attr(href)').getall()
        #titulos = response.css('a::attr(target)')
        #yield {"forum_title": (response.url,links),'titulos':titulos}
        
        # Obtener los enlaces y nombres de los foros solo los foros
        for forum in response.css('a[href^="forum_topics.asp"]'):
            forum_url = forum.css('a::attr(href)').get()
            forum_name = forum.css('a::text').get()
            print(forum_name)
            yield {
                'forum_url': forum_url,
                'forum_name': forum_name,
                'next_urls': self.root_urls+forum_url
            }
            self.links_no_vistos.append(forum_url)
            # Seguir el enlace del foro para obtener más información
            #yield response.follow(self.root_urls+forum_url, callback=self.parse_forum)
        # Después de procesar los foros en la página principal, continuar rastreando la página principal
        if len(self.links_no_vistos)>0:
            
            next_page = self.links_no_vistos.pop()
            #print(self.root_urls + next_page)
            self.links_vistos.append(next_page)
            yield response.follow(self.root_urls + next_page, callback=self.parse_forum)

        def parse_forum(self, response):
            print("URL de la página actual:", response.url)
            # Aquí puedes realizar el scraping de la información dentro del foro
            # Por ejemplo, si deseas extraer el texto de los mensajes, puedes hacerlo aquí
            # messages = response.css('div.mensaje::text').getall()
            # href="forum_posts.asp?TID=5496&PN=1"
            #self.links_vistos.append(self.links_no_vistos)
            
            for forum in response.css('a[href^="forum_posts.asp"]'):
                forum_url = forum.css('a::attr(href)').get()
                forum_name = forum.css('a::text').get()

                yield {
                    'forum_url': forum_url,
                    'forum_name': forum_name
                    }
            #print(len(self.links_no_vistos))
            #if len(self.links_no_vistos)>0:
            #    next_page = self.links_no_vistos.pop()
            #    self.links_vistos.append(next_page)
            #    yield response.follow(self.root_urls + next_page, callback=self.parse_forum)

@wait_for(10)
def run_spider():
    """run spider with MJKQuotesToCsv"""
    crawler = CrawlerRunner()
    d = crawler.crawl(QuotesToCsv)
    return d

# %%
import scrapy
from scrapy.crawler import CrawlerRunner
from crochet import setup, wait_for

setup()

class QuotesToCsv(scrapy.Spider):
    name = "MJKQuotesToCsv"
    start_urls = ['https://www.ludopatia.org/forum/default.asp']

    custom_settings = {
        'FEEDS': {
            'quotes.json': {
                'format': 'json',
                'overwrite': True
            }
        }
    }

    def start_requests(self):
        url = "https://www.ludopatia.org/forum/default.asp"
        self.root_urls = 'https://www.ludopatia.org/forum/'
        self.links_no_vistos = []
        self.links_vistos = []
        yield scrapy.Request(url, self.parse)

    def parse(self, response):
        print("URL de la página actual:", response.url)
        
        for forum in response.css('a[href^="forum_topics.asp"]'):
            forum_url = forum.css('a::attr(href)').get()
            forum_name = forum.css('a::text').get()
            print(forum_name)
            yield {
                'forum_url': forum_url,
                'forum_name': forum_name,
                'next_urls': self.root_urls + forum_url
            }
            self.links_no_vistos.append(self.root_urls + forum_url)
        
        if len(self.links_no_vistos) > 0:
            next_page = self.links_no_vistos.pop()
            self.links_vistos.append(next_page)
            yield response.follow(next_page, callback=self.parse_forum)

    def parse_forum(self, response):
        print("URL de la página actual:", response.url)
        
        for forum in response.css('a[href^="forum_posts.asp"]'):
            forum_url = forum.css('a::attr(href)').get()
            forum_name = forum.css('a::text').get()

            yield {
                'forum_url': forum_url,
                'forum_name': forum_name
            }

        if len(self.links_no_vistos) > 0:
            next_page = self.links_no_vistos.pop()
            self.links_vistos.append(next_page)
            yield response.follow(next_page, callback=self.parse_forum)

@wait_for(10)
def run_spider():
    crawler = CrawlerRunner()
    d = crawler.crawl(QuotesToCsv)
    return d

# %%
run_spider()
# Out:
# URL de la página actual: https://www.ludopatia.org/forum/default.asp
# ASAMBLEA  FORA DE JOC
# ASAMBLEA  AAFAL
# General de ayuda
# Distracciones
# CIENCIA Y DOCUMENTACION
# Soporte General. Ayuda Técnica.Tratamiento Ludopatia
# Quejas y sugerencias
# ENCUESTA 2010
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=13
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=11
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=6
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=12
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=10
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=1
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=17
# URL de la página actual: https://www.ludopatia.org/forum/forum_topics.asp?FID=16

# %%
import scrapy
from scrapy.crawler import CrawlerRunner
from crochet import setup, wait_for

setup()

class QuotesToCsv(scrapy.Spider):
    name = "MJKQuotesToCsv"
    start_urls = ['https://www.ludopatia.org/forum/default.asp']

    custom_settings = {
        'FEEDS': {
            'quotes.json': {
                'format': 'json',
                'overwrite': True
            }
        }
    }

    def start_requests(self):
        url = "https://www.ludopatia.org/forum/default.asp"
        self.root_url = 'https://www.ludopatia.org/forum/'
        yield scrapy.Request(url, self.parse)

    def parse(self, response):
        print("URL de la página actual:", response.url)

        for forum in response.css('a[href^="forum_topics.asp"]'):
            forum_url = forum.css('a::attr(href)').get()
            forum_name = forum.css('a::text').get()
            forum_full_url = self.root_url + forum_url
            print(forum_name)
            yield {
                'dad_url':response.url,
                'forum_url': forum_full_url,
                'forum_name': forum_name,
            }

            yield response.follow(forum_full_url, callback=self.parse_forum)

    def parse_forum(self, response):
        print("URL de la página actual forum:", response.url)

        for forum in response.css('a[href^="forum_posts.asp"]'):
            forum_url = forum.css('a::attr(href)').get()
            forum_name = forum.css('a::text').get()
            forum_full_url = self.root_url + forum_url

            yield {
                'dad_url':response.url,
                'forum_url': forum_full_url,
                'forum_name': forum_name
            }
            yield response.follow(forum_full_url, callback=self.parse_subforum)
            
            
    def parse_subforum(sel,response):
        print("URL de la página actual sub:", response.url)
        #print(response.css)
        # Extracting data from the current page
        # Extracting data from the current page
        rows = response.xpath('//tr[td[@valign="top"]]')
        #print(rows)
        for row in rows:
            authors = row.xpath('//span[@class="bold"]/text()').getall()
            message_bodies = row.xpath('//td[@class="text"]/text()').getall()
            print(authors)
            print(message_bodies)
            # Ensure authors and message_bodies are of the same length
            if len(authors) != len(message_bodies):
                self.logger.warning("Mismatch between authors and message bodies!")

            for  message_body in message_bodies:
                print("a")
                #author = author.strip() if author else ""
                message_body = message_body.strip() if message_body else ""

                #print(f'Author: {authors}')
                print(f'Message Body: {message_body}')
            
            
        for subforum in response.css('a[href^="subforum.asp"]'):
            subforum_url = subforum.css('a::attr(href)').get()
            subforum_name = subforum.css('a::text').get()
            subforum_full_url = self.root_url + subforum_url
            # Extraer la información del post
            

            yield {
                'subforum_url': subforum_full_url,
                'subforum_name': subforum_name,
                'post_author': subforum.css('.bold::text').get(),
                'post_content': subforum.css('.text::text').get(),
                'post_date': subforum.css('.smText::text').re_first(r'Escrito el: (.+?)$'),
                
            }

            #yield response.follow(subforum_full_url, callback=self.parse_forum)

@wait_for(10)
def run_spider():
    crawler = CrawlerRunner()
    d = crawler.crawl(QuotesToCsv)
    return d

# %%
run_spider()
# Out:
# URL de la página actual: https://www.ludopatia.org/forum/default.asp
# ASAMBLEA  FORA DE JOC
# ASAMBLEA  AAFAL
# General de ayuda
# Distracciones
# CIENCIA Y DOCUMENTACION
# Soporte General. Ayuda Técnica.Tratamiento Ludopatia
# Quejas y sugerencias
# ENCUESTA 2010
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=13
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=16
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=12
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=11
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=1
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=6
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=10
# URL de la página actual forum: https://www.ludopatia.org/forum/forum_topics.asp?FID=17
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2070&PN=1&get=last
# ['administrator', 'siemprejuntos', 'siemprejuntos', 'siemprejuntos', 'siemprejuntos', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2034&PN=1&get=last
# ['administrator', 'JosepGa', 'administrator', 'JosepGa', 'administrator', 'xavier', 'administrator', 'paul05', 'delina', 'juan33']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2070&PN=1&TPN=2
# ['esteban', 'guatiza', 'administrator', 'guatiza', 'joni', 'administrator', 'the2', 'Made', 'administrator', 'Made', 'jose mario', 'administrator', 'malv1990', 'Eclipse', 'alternova', 'administrator', 'ronenpasas', 'maripepa', 'administrator', 'Unomás']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2034&PN=1
# ['administrator', 'JosepGa', 'administrator', 'JosepGa', 'administrator', 'xavier', 'administrator', 'paul05', 'delina', 'juan33']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2070&PN=1&TPN=3
# ['administrator', 'siemprejuntos', 'siemprejuntos', 'siemprejuntos', 'siemprejuntos', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2070&PN=1&TPN=1
# ['administrator', 'Capito', 'administrator', 'PACO', 'administrator', 'marioea_pe', 'administrator', 'marioea_pe', 'gallito', '1313', 'elv1s', 'MOLIS', 'capirosi', 'Karlota', 'tato', 'FrandeGranada', 'FrandeGranada', 'mcalvete', 'Anayuo', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2070&PN=1
# ['administrator', 'Capito', 'administrator', 'PACO', 'administrator', 'marioea_pe', 'administrator', 'marioea_pe', 'gallito', '1313', 'elv1s', 'MOLIS', 'capirosi', 'Karlota', 'tato', 'FrandeGranada', 'FrandeGranada', 'mcalvete', 'Anayuo', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=5496&PN=1&get=last
# ['administrator', 'JugadorX', 'administrator', 'JugadorX', 'administrator', 'JugadorX', 'jignacio', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=5496&PN=1&TPN=2
# ['administrator', 'JugadorX', 'administrator', 'JugadorX', 'administrator', 'JugadorX', 'jignacio', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=5496&PN=1&TPN=1
# ['administrator', 'luisafernandez', 'administrator', 'jasito', 'administrator', 'JOSE HUMBERTO', 'administrator', 'chematc', 'administrator', 'Analiss', 'Esthereta', 'administrator', 'karla-ayuda', 'caro82', 'administrator', 'Eduardo', 'administrator', 'JugadorX', 'administrator', 'JugadorX']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=5496&PN=1
# ['administrator', 'luisafernandez', 'administrator', 'jasito', 'administrator', 'JOSE HUMBERTO', 'administrator', 'chematc', 'administrator', 'Analiss', 'Esthereta', 'administrator', 'karla-ayuda', 'caro82', 'administrator', 'Eduardo', 'administrator', 'JugadorX', 'administrator', 'JugadorX']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=9594&PN=1&get=last
# ['la_maza', 'torito', 'JulioC', 'torito', 'Constante', 'torito', 'El Tico', 'kiko.', 'El Tico', 'DiegoDago', 'torito', 'DiegoDago', 'El Tico', 'mandalo', 'DiegoDago', 'mandalo', 'Constante', 'DiegoDago', 'Tigre']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=9594&PN=1
# ['la_maza', 'torito', 'JulioC', 'torito', 'Constante', 'torito', 'El Tico', 'kiko.', 'El Tico', 'DiegoDago', 'torito', 'DiegoDago', 'El Tico', 'mandalo', 'DiegoDago', 'mandalo', 'Constante', 'DiegoDago', 'Tigre']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=9928&PN=1&get=last
# ['Tigre']
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /tmp/ipykernel_17252/3414120260.py in <module>
# ----> 1 run_spider()
#
# ~/anaconda3/envs/TGINE/lib/python3.7/site-packages/crochet/_eventloop.py in wrapper(function, _, args, kwargs)
#     459                 eventual_result = run()
#     460                 try:
# --> 461                     return eventual_result.wait(timeout)
#     462                 except TimeoutError:
#     463                     eventual_result.cancel()
#
# ~/anaconda3/envs/TGINE/lib/python3.7/site-packages/crochet/_eventloop.py in wait(self, timeout)
#     194                 "EventualResult.wait() must not be run in the reactor thread.")
#     195
# --> 196         result = self._result(timeout)
#     197         if isinstance(result, Failure):
#     198             result.raiseException()
#
# ~/anaconda3/envs/TGINE/lib/python3.7/site-packages/crochet/_eventloop.py in _result(self, timeout)
#     173         # have to check manually:
#     174         if not self._result_set.is_set():
# --> 175             raise TimeoutError()
#     176         self._result_retrieved = True
#     177         return self._value
#
# TimeoutError:
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=9928&PN=1
# ['Tigre']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2403&PN=1&get=last
# ['mac1971', 'elpaterita', 'mac1971']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2403&PN=1
# ['mac1971', 'elpaterita', 'mac1971']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2871&PN=1&get=last
# ['MAR.', 'administrator', 'elpaterita', 'MAR.']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2871&PN=1
# ['MAR.', 'administrator', 'elpaterita', 'MAR.']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=3295&PN=1&get=last
# ['elpaterita', 'administrator', 'elpaterita']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=3295&PN=1
# ['elpaterita', 'administrator', 'elpaterita']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=3423&PN=1&get=last
# ['Jesús', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=3423&PN=1
# ['Jesús', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2796&PN=1&get=last
# ['MAR.', 'MAR.', 'maria jose cerr', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=2796&PN=1
# ['MAR.', 'MAR.', 'maria jose cerr', 'administrator']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=1876&PN=1&get=last
# ['JOSE MARIA', 'administrator', 'JOSE MARIA', 'CuiCui']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=1876&PN=1
# ['JOSE MARIA', 'administrator', 'JOSE MARIA', 'CuiCui']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=4022&PN=1&get=last
# ['H&V.', 'administrator', 'CuiCui', 'chamy']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=4022&PN=1
# ['H&V.', 'administrator', 'CuiCui', 'chamy']
# URL de la página actual sub: https://www.ludopatia.org/forum/forum_posts.asp?TID=4924&PN=1&get=last
# ['chamy', 'chamy', 'administrator', 'chamy', 'Jarabito', 'CuiCui']
